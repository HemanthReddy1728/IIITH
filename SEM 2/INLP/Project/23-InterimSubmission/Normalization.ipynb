# %%
import pandas as pd
# from indicnlp.normalize.indic_normalize import IndicNormalizerFactory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os 
os.chdir("/content/drive/MyDrive/HASOC-2021/Subtask1-Marathi/Data")

# %%
df = pd.read_excel('./mr_Hasoc2021_train.xlsx')
df.head()
# Out:
#       text_id                                               text task_1
# 0  hasoc_mr_1  भारत 15 ऑगस्ट 1947 ला स्वतंत्र झाला आणि त्यानं...    NOT
# 1  hasoc_mr_2  स्वत ला हवा तसा बाइट किंवा प्रतिक्रिया घेण्यास...    NOT
# 2  hasoc_mr_3  5 व्या नंबरची अर्थव्यवस्था आहे भारताची जगात 20...    NOT
# 3  hasoc_mr_4      च्यायला म्हणजे दुबईचा फोन ही पुडीच निघाली की.    HOF
# 4  hasoc_mr_5  ह्याला खरंतर कधीच आत टाकला पाहिजे होता. पैसा आ...    HOF

# %%
hate_rows = df[(df.task_1 == 'HOF')]

# %%
hate_rows.shape
# Out:
# (669, 3)

# %%
not_rows = df[(df.task_1 == 'NOT')]

# %%
not_rows.shape
# Out:
# (1205, 3)

# %%
factory=IndicNormalizerFactory()
normalizer=factory.get_normalizer("mr")

num_rows = df.shape[0]
for i in range(num_rows):
    input_text = df["text"][i]
    normalized_text = normalizer.normalize(df["text"][i])
    if (input_text != normalized_text):
        print()
        print("Original   ->",input_text)
        print("Normalized ->",normalized_text)
    df["text"][i] = normalized_text
# Out:
# Original   -> भारत 15 ऑगस्ट 1947 ला स्वतंत्र झाला आणि त्यानंतर तब्बल 2.5 वर्षांनी म्हणजे 26 जानेवारी 1950 साली भारताला राज्यघ…
# Normalized -> भारत 15 ऑगस्ट 1947 ला स्वतंत्र झाला आणि त्यानंतर तब्बल 2.5 वर्षांनी म्हणजे 26 जानेवारी 1950 साली भारताला राज्यघ...
#
# Original   -> स्वत ला हवा तसा बाइट किंवा प्रतिक्रिया घेण्यासाठी ॲन्करबाई किती हट्टाला पेटलीय. जोरजबरदस्तीने तोंडात वाक्य घुसवतेय.
# Normalized -> स्वत ला हवा तसा बाइट किंवा प्रतिक्रिया घेण्यासाठी एन्करबाई किती हट्टाला पेटलीय. जोरजबरदस्तीने तोंडात वाक्य घुसवतेय.
#
# Original   -> 5 व्या नंबरची अर्थव्यवस्था आहे भारताची जगात 2014 पर्यंत.... चंप्या  आता पण 5 वर आहे... अण…
# Normalized -> 5 व्या नंबरची अर्थव्यवस्था आहे भारताची जगात 2014 पर्यंत.... चंप्या  आता पण 5 वर आहे... अण...
#
# Original   -> ह्याला खरंतर कधीच आत टाकला पाहिजे होता. पैसा आणि स्टारडमच्या जोरावर चाललाय सगळं. एकदा ह्याच्यावर घाल…
# Normalized -> ह्याला खरंतर कधीच आत टाकला पाहिजे होता. पैसा आणि स्टारडमच्या जोरावर चाललाय सगळं. एकदा ह्याच्यावर घाल...
#
# ...

# %%
train=df.sample(frac=0.8,random_state=73)
test=df.drop(train.index)
train.to_csv('norm_train_mar.csv')
test.to_csv('norm_test_mar.csv')
