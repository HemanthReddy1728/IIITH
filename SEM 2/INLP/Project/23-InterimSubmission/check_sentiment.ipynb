# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir("/content/drive/My Drive/HASOC-2021/Subtask1-Marathi")

# %%
df = pd.read_csv("sentiment.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     text_id  ... sentiment     score
# 0           0  hasoc_mr_1  ...   Neutral  0.995531
# 1           1  hasoc_mr_2  ...   Neutral  0.987465
# 2           2  hasoc_mr_3  ...   Neutral  0.676124
# 3           3  hasoc_mr_4  ...  Negative  0.959779
# 4           4  hasoc_mr_5  ...  Negative  0.965509
#
# [5 rows x 6 columns]

# %%
negative_hate = df[(df.task_1 == "HOF") & (df.sentiment == "Negative")]
positive_hate = df[(df.task_1 == "HOF") & (df.sentiment == "Positive")]
neutral_hate = df[(df.task_1 == "HOF") & (df.sentiment == "Neutral")]

negative_not = df[(df.task_1 == "NOT") & (df.sentiment == "Negative")]
positive_not = df[(df.task_1 == "NOT") & (df.sentiment == "Positive")]
neutral_not = df[(df.task_1 == "NOT") & (df.sentiment == "Neutral")]

# %%
negative_hate.size
# Out:
# 1236

# %%
positive_hate.size
# Out:
# 360

# %%
neutral_hate.size
# Out:
# 2418

# %%
negative_not.size
# Out:
# 1686

# %%
positive_not.size
# Out:
# 1218

# %%
neutral_not.size
# Out:
# 4326
