# %% [markdown]
# # SMAI Assignment - 2
#
# ## Question 3: Face Recognition using Principal Component Analysis
#
# This question requires you to create a basic facial recognition system using a technique called principal component analysis (PCA)
# by projecting the face images on the feature space (face space) which best
# represents the variations among distinct faces. The face space is defined as the
# “Eigenfaces", which are the eigenvectors of the set of faces.
#
# The goal of implementing this system is to recognize a person's face by comparing it to a pre-existing database of faces, and identifying the closest match.
#
# The AT&T face dataset contains a set of grayscale face images with dimensions 92x112. The images are organised in 40 directories (one for each subject), which have names of the form sX, where X indicates the subject number (between 1 and 40). In each of these directories, there are ten different images of that subject, which have names of the form Y.pgm, where Y is the image number for that subject (between 1 and 10). These 10 images per person are taken at different times, varying the lighting, facial expressions (open / closed eyes, smiling / not smiling) and facial details (glasses / no glasses). All the images were taken against a dark homogeneous background with the subjects in an upright, frontal position (with tolerance for some side movement).
#
# Link to paper on Eigenfaces: [https://sites.cs.ucsb.edu/~mturk/Papers/mturk-CVPR91.pdf](https://sites.cs.ucsb.edu/~mturk/Papers/mturk-CVPR91.pdf)
#
# <b>Link:</b> [https://git-disl.github.io/GTDLBench/datasets/att_face_dataset/](https://git-disl.github.io/GTDLBench/datasets/att_face_dataset/)
#
# #### Tasks:
# 1. Load dataset and divide the data into training and test sets.
# 2. Implement the PCA algorithm from scratch.
# 3. Implement image reconstruction using the eigen projections and visualise differences for different number of components.
# 4. Visualise the mean(Eigen face) generated.
# 5. Given training set, obtain accuracy by attempting a face regonition module and obtaining the accuracy for different number of principal components.

# %% [markdown]
# #### Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import os, sys
import cv2
from copy import copy
from tqdm import tqdm
import pandas as pd
from google.colab.patches import cv2_imshow
from os import walk, path
from more_itertools import chunked
import random

# %%
# !gdown 1CqqAePNPXuvBYDDDajnHFnvgq-Xr1Zyi
# !unzip "/content/ATnT.zip" -d "/content"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1CqqAePNPXuvBYDDDajnHFnvgq-Xr1Zyi
# To: /content/ATnT.zip
# 100% 3.77M/3.77M [00:00<00:00, 132MB/s]
# Archive:  /content/ATnT.zip
# replace /content/ATnT/README? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/ATnT/README
#   inflating: /content/ATnT/s1/1.pgm
#   inflating: /content/ATnT/s1/10.pgm
#   inflating: /content/ATnT/s1/2.pgm
#   inflating: /content/ATnT/s1/3.pgm
#   inflating: /content/ATnT/s1/4.pgm
#   inflating: /content/ATnT/s1/5.pgm
#   inflating: /content/ATnT/s1/6.pgm
#   inflating: /content/ATnT/s1/7.pgm
#   inflating: /content/ATnT/s1/8.pgm
#   inflating: /content/ATnT/s1/9.pgm
#   inflating: /content/ATnT/s10/1.pgm
#   inflating: /content/ATnT/s10/10.pgm
#   inflating: /content/ATnT/s10/2.pgm
#   inflating: /content/ATnT/s10/3.pgm
#   inflating: /content/ATnT/s10/4.pgm
#   inflating: /content/ATnT/s10/5.pgm
#   inflating: /content/ATnT/s10/6.pgm
#   inflating: /content/ATnT/s10/7.pgm
#   inflating: /content/ATnT/s10/8.pgm
#   inflating: /content/ATnT/s10/9.pgm
#   inflating: /content/ATnT/s11/1.pgm
#   inflating: /content/ATnT/s11/10.pgm
#   inflating: /content/ATnT/s6/10.pgm
#   inflating: /content/ATnT/s6/2.pgm
#   inflating: /content/ATnT/s6/3.pgm
#   inflating: /content/ATnT/s6/4.pgm
#   inflating: /content/ATnT/s6/5.pgm
#   inflating: /content/ATnT/s6/6.pgm
#   inflating: /content/ATnT/s6/7.pgm
#   inflating: /content/ATnT/s6/8.pgm
#   inflating: /content/ATnT/s6/9.pgm
#   inflating: /content/ATnT/s7/1.pgm
#   inflating: /content/ATnT/s7/10.pgm
#   inflating: /content/ATnT/s7/2.pgm
#   inflating: /content/ATnT/s7/3.pgm
#   inflating: /content/ATnT/s7/4.pgm
#   inflating: /content/ATnT/s7/5.pgm
#   inflating: /content/ATnT/s7/6.pgm
#   inflating: /content/ATnT/s7/7.pgm
#   inflating: /content/ATnT/s7/8.pgm
#   inflating: /content/ATnT/s7/9.pgm
#   inflating: /content/ATnT/s8/1.pgm
#   inflating: /content/ATnT/s8/10.pgm
#   inflating: /content/ATnT/s8/2.pgm
#   inflating: /content/ATnT/s8/3.pgm
#   inflating: /content/ATnT/s8/4.pgm
#   inflating: /content/ATnT/s8/5.pgm
#   inflating: /content/ATnT/s8/6.pgm
#   inflating: /content/ATnT/s8/7.pgm
#   inflating: /content/ATnT/s8/8.pgm
#   inflating: /content/ATnT/s8/9.pgm
#   inflating: /content/ATnT/s9/1.pgm
#   inflating: /content/ATnT/s9/10.pgm
#   inflating: /content/ATnT/s9/2.pgm
#   inflating: /content/ATnT/s9/3.pgm
#   inflating: /content/ATnT/s9/4.pgm
#   inflating: /content/ATnT/s9/5.pgm
#   inflating: /content/ATnT/s9/6.pgm
#   inflating: /content/ATnT/s9/7.pgm
#   inflating: /content/ATnT/s9/8.pgm
#   inflating: /content/ATnT/s9/9.pgm

# %%
def print_face_dictionary(att_faces_dict):
    for keys in att_faces_dict:
        print(keys, att_faces_dict[keys])
    # print(keys)

att_faces_dict = {}
for dir_path, dir_names, file_names in walk('./ATnT'):
    for file in file_names:
        image_filename = path.join(dir_path, file)
        # print(image_filename)
        image_frame = cv2.imread(image_filename, 0)
        # print(image_frame)

        if image_frame is not None:
        #   print(image_frame.shape)
        # cv2.imshow('image', frame)
        #   cv2_imshow(image_frame)
        # image_frame_col = np.array(image_frame, dtype='float64').flatten()
        # print(image_frame_col)
            att_faces_dict[image_filename] = image_frame

# att_faces_dict = dict(sorted(att_faces_dict.items()))
# print_face_dictionary(att_faces_dict)

# %% [markdown]
# #### Import Dataset
# Assign labels for the images based on the subdirectories to obtain X(images array) and y (labels).
#
# Ensure that the test data contains atleast one image from each category.

# %%
# from google.colab import drive, patches
# drive.mount('/content/drive')

# %%
# iterate through all folders, load each image
# fol_path = '/content/drive/MyDrive/SMAI/A2/q3/ATnT'
# fol_path = './AtnT'

# trainAmt = 0.9
# allFaces = []
# labels = []

# for i in range(1,41):
#     for j in range(1,11):
#         imgPath = os.path.join("ATnT", "s" + str(i), str(j) + ".pgm")
#         # imgPath = os.path.join(fol_path, "s" + str(i), str(j) + ".pgm")
#         # print(imgPath)
#         img = cv2.imread(imgPath, -1)
#         # patches.cv2_imshow(img)
#         allFaces.append(img)
#         labels.append(i)

# # shuffle
# randomOrder = np.random.permutation(len(labels))
# allFaces = np.array(allFaces)[randomOrder]
# labels = np.array(labels)[randomOrder]

# # split
# trainFaces = allFaces[:int(trainAmt*len(allFaces))]
# trainLabels = labels[:int(trainAmt*len(allFaces))]

# testFaces = allFaces[int(trainAmt*len(allFaces)): ]
# testLabels = labels[int(trainAmt*len(allFaces)): ]

# # 112x92 (= 10304) grayscale images,  360 in train, 40 in test
# print(trainFaces.shape, trainLabels.shape, testFaces.shape, testLabels.shape)
# print(trainFaces)
# print(trainLabels)
# print(testFaces)
# print(testLabels)

X_train = [] # train_face_set
y_train = [] # train_face_labels
X_test = [] # test_face_set
y_test = [] # test_face_labels

for keys_chunk in chunked(att_faces_dict.keys(), 10):
    # print(keys_chunk)
    # Select a random key from the chunk
    random_key = random.choice(keys_chunk)
    # print(random_key)
    # Iterate over the keys in the chunk
    for key in keys_chunk:
        # print(key)
    #     # keys_list = key.split('/')
    #     # print("keys_list",end="")
    #     # print(keys_list)
    #     # label_list = keys_list[3].split('.')
    #     # print("label_list",end="")
    #     # print(label_list)

    #     # image_label = key
        if key == random_key: # keeping 8.pgm from each folder as test data
            X_test.append(att_faces_dict[key].flatten())
            y_test.append(key)
        else:
            X_train.append(att_faces_dict[key].flatten())
            y_train.append(key)

print(X_train)
print(y_train)
print(X_test)
print(y_test)
X_train = np.array(X_train)
X_test = np.array(X_test)
print()
print(X_train.shape)
print(X_train)
print()
print(X_test.shape)
print(X_test)
print()
print(len(y_train))
print(y_train)
print()
print(len(y_test))
print(y_test)
# Out:
# [array([ 98, 100,  99, ...,  53,  48,  52], dtype=uint8), array([101, 100,  99, ...,  49,  52,  52], dtype=uint8), array([105, 106, 100, ...,  76,  76,  76], dtype=uint8), array([104, 101, 104, ...,  78,  73,  79], dtype=uint8), array([ 99, 102,  97, ...,  50,  53,  50], dtype=uint8), array([ 98, 103,  98, ...,  57,  50,  48], dtype=uint8), array([105, 107, 104, ...,  77,  76,  75], dtype=uint8), array([104,  98, 100, ...,  52,  49,  53], dtype=uint8), array([102, 105, 104, ...,  74,  74,  75], dtype=uint8), array([53, 58, 57, ..., 38, 47, 39], dtype=uint8), array([48, 45, 50, ..., 46, 50, 53], dtype=uint8), array([52, 41, 48, ..., 44, 43, 46], dtype=uint8), array([49, 45, 46, ..., 43, 42, 45], dtype=uint8), array([45, 52, 48, ..., 48, 43, 47], dtype=uint8), array([50, 57, 56, ..., 39, 46, 43], dtype=uint8), array([53, 52, 61, ..., 46, 45, 45], dtype=uint8), array([52, 56, 60, ..., 39, 41, 44], dtype=uint8), array([47, 43, 48, ..., 45, 49, 50], dtype=uint8), array([ 58,  55,  52, ..., 131, 115,  68], dtype=uint8), array([ 54,  55,  60, ..., 156, 181, 217], dtype=uint8), array([ 56,  58,  50, ...,  63,  75, 189], dtype=uint8), array([ 58,  57,  61, ..., 204, 102,  98], dtype=uint8), array([ 55,  56,  56, ...,  69, 144, 193], dtype=uint8), array([ 58,  54,  57, ...,  97, 115, 128], dtype=uint8), array([ 50,  54,  61, ..., 152, 165,  67], dtype=uint8), array([ 49,  65,  53, ..., 134, 130, 145], dtype=uint8), array([ 54,  53,  53, ..., 227, 104, 125], dtype=uint8), array([ 44,  50,  46, ..., 140, 104,  95], dtype=uint8), array([ 51,  46,  48, ..., 196, 173, 110], dtype=uint8), array([ 44,  44,  47, ..., 188, 165, 106], dtype=uint8), array([ 43,  46,  43, ...,  95, 162, 197], dtype=uint8), array([ 41,  42,  47, ..., 141, 156, 149], dtype=uint8), array([ 44,  48,  51, ..., 129, 131, 125], dtype=uint8), array([ 52,  39,  51, ..., 133, 138, 103], dtype=uint8), array([ 46,  50,  45, ..., 136, 144,  98], dtype=uint8), array([ 47,  46,  46, ..., 151, 143,  90], dtype=uint8), array([133, 132, 131, ...,  53,  48,  58], dtype=uint8), array([130, 132, 129, ...,  53,  50,  52], dtype=uint8), array([132, 127, 128, ...,  85,  83,  85], dtype=uint8), array([131, 133, 128, ...,  54,  53,  56], dtype=uint8), array([126, 127, 126, ...,  87,  85,  89], dtype=uint8), array([130, 133, 129, ...,  54,  54,  56], dtype=uint8), array([131, 129, 130, ...,  51,  48,  55], dtype=uint8), array([128, 125, 126, ...,  84,  85,  85], dtype=uint8), array([128, 128, 128, ...,  87,  83,  86], dtype=uint8), array([110, 111, 110, ...,  63,  59,  60], dtype=uint8), array([112, 110, 113, ..., 157, 159, 167], dtype=uint8), array([110, 110, 112, ..., 141,  88,  64], dtype=uint8), array([109, 107, 108, ...,  66,  67,  67], dtype=uint8), array([108, 108, 106, ...,  69,  69,  70], dtype=uint8), array([110, 113, 108, ...,  63,  63,  61], dtype=uint8), array([110, 108, 109, ...,  66,  64,  63], dtype=uint8), array([112, 109, 112, ...,  61,  62,  62], dtype=uint8), array([106, 106, 110, ...,  69,  69,  68], dtype=uint8), array([38, 35, 40, ..., 36, 35, 39], dtype=uint8), array([ 45,  38,  40, ..., 135,  24,  36], dtype=uint8), array([119, 123, 123, ...,  78,  72,  75], dtype=uint8), array([119, 121, 123, ...,  73,  74,  76], dtype=uint8), array([120, 119, 121, ...,  74,  74,  80], dtype=uint8), array([39, 41, 37, ..., 33, 33, 40], dtype=uint8), array([39, 40, 38, ..., 36, 38, 40], dtype=uint8), array([117, 122, 120, ...,  76,  78,  71], dtype=uint8), array([38, 41, 37, ..., 39, 38, 40], dtype=uint8), array([36, 39, 45, ..., 52, 51, 53], dtype=uint8), array([37, 36, 38, ..., 40, 50, 50], dtype=uint8), array([40, 42, 41, ..., 57, 37, 42], dtype=uint8), array([36, 38, 37, ..., 48, 51, 50], dtype=uint8), array([34, 38, 40, ..., 60, 57, 59], dtype=uint8), array([35, 36, 37, ..., 59, 57, 58], dtype=uint8), array([35, 35, 35, ..., 56, 58, 55], dtype=uint8), array([40, 41, 43, ..., 40, 37, 36], dtype=uint8), array([ 35,  40,  38, ..., 222,  55,  34], dtype=uint8), array([48, 49, 45, .. ...
ATnT/s11/5.pgm', './ATnT/s25/1.pgm', './ATnT/s25/2.pgm', './ATnT/s25/8.pgm', './ATnT/s25/7.pgm', './ATnT/s25/10.pgm', './ATnT/s25/9.pgm', './ATnT/s25/3.pgm', './ATnT/s25/5.pgm', './ATnT/s25/6.pgm', './ATnT/s19/1.pgm', './ATnT/s19/8.pgm', './ATnT/s19/7.pgm', './ATnT/s19/10.pgm', './ATnT/s19/9.pgm', './ATnT/s19/4.pgm', './ATnT/s19/3.pgm', './ATnT/s19/5.pgm', './ATnT/s19/6.pgm', './ATnT/s37/1.pgm', './ATnT/s37/8.pgm', './ATnT/s37/7.pgm', './ATnT/s37/ ...
#
# 40
# ['./ATnT/s29/5.pgm', './ATnT/s17/1.pgm', './ATnT/s22/8.pgm', './ATnT/s14/1.pgm', './ATnT/s5/10.pgm', './ATnT/s30/1.pgm', './ATnT/s15/2.pgm', './ATnT/s24/3.pgm', './ATnT/s1/5.pgm', './ATnT/s2/6.pgm', './ATnT/s33/9.pgm', './ATnT/s35/5.pgm', './ATnT/s4/4.pgm', './ATnT/s12/6.pgm', './ATnT/s7/7.pgm', './ATnT/s34/1.pgm', './ATnT/s40/3.pgm', './ATnT/s9/2.pgm', './ATnT/s16/8.pgm', './ATnT/s11/6.pgm', './ATnT/s25/4.pgm', './ATnT/s19/2.pgm', './ATnT/s37/2.pgm', './ATnT/s36/1.pgm', './ATnT/s20/4.pgm', './ATnT/s18/6.pgm', './ATnT/s13/10.pgm', './ATnT/s6/8.pgm', './ATnT/s8/1.pgm', './ATnT/s27/8.pgm', './ATnT/s21/7.pgm', './ATnT/s31/8.pgm', './ATnT/s23/5.pgm', './ATnT/s3/3.pgm', './ATnT/s26/1.pgm', './ATnT/s38/9.pgm', './ATnT/s28/5.pgm', './ATnT/s10/8.pgm', './ATnT/s39/6.pgm', './ATnT/s32/3.pgm']

# %% [markdown]
# #### Implement PCA Algorithm.

# %% [markdown]
# Explain your steps with comments and write a brief explanation of the method.

# %%
class principalComponentAnalysis:
    def __init__(self, number_of_components=None, mean=None):
        self.components = None
        self.number_of_components = number_of_components
        self.mean = None
        self.eigenvectors = None
        self.eigenvalues = None
        self.eigenfaces = None

    def fit(self, X):
        # Mean centering
        self.mean = np.mean(X, axis=0)
        X = X - self.mean

        # covariance, function needs samples as columns
        cov = np.cov(X.T)
        # print(cov)
        # print(np.dot(X.T, X) / X.shape[0])

        # eigenvalues, eigenvectors
        self.eigenvalues, self.eigenvectors = np.linalg.eigh(cov)

        # -> eigenvector v = [:,i] column vector, transpose for easier calculations
        # sort eigenvectors
        self.eigenvectors = self.eigenvectors.T
        idxs = np.argsort(self.eigenvalues)[::-1]
        self.eigenvalues = self.eigenvalues[idxs]
        self.eigenvectors = self.eigenvectors[idxs]

        # store first n self.eigenvectors
        self.components = self.eigenvectors[0 : self.number_of_components]

        self.eigenfaces = self.components

        return X, self.mean, self.eigenvalues, self.eigenvectors, self.eigenfaces

    def transform(self, X):
        # project data
        X = X - self.mean
        # return np.dot(X, self.components.T)
        weights = (self.eigenfaces @ X.T)
        return weights

    def getEigenFacesAndWeights(self, X, first_n_components):
        X = X - self.mean
        first_n_eigenfaces = self.eigenvectors[0 : first_n_components]
        first_n_eigenfaces_weights = (first_n_eigenfaces @ X.T)
        return first_n_eigenfaces, first_n_eigenfaces_weights



pca = principalComponentAnalysis(number_of_components=100)
X_mean, mean, eigenvalues, eigenvectos, eigenfaces = pca.fit(X_train)

# %% [markdown]
# Sure, here's a step-by-step explanation of the methods defined in the `principalComponentAnalysis` class along with comments:
#
# ```python
# class principalComponentAnalysis:
#     def __init__(self, number_of_components=None, mean=None):
#         self.components = None
#         self.number_of_components = number_of_components
#         self.mean = None
#         self.eigenvectors = None
#         self.eigenvalues = None
#         self.eigenfaces = None
# ```
# This is the constructor method `__init__`. It initializes various attributes of the PCA class including the number of components to keep (`number_of_components`), mean, eigenvectors, eigenvalues, and eigenfaces.
#
# ```python
#     def fit(self, X):
#         # Mean centering
#         self.mean = np.mean(X, axis=0)
#         X = X - self.mean
# ```
# The `fit` method calculates the mean of the input data `X` and then subtracts this mean from each data point to center the data around zero.
#
# ```python
#         # covariance, function needs samples as columns
#         cov = np.cov(X.T)
# ```
# The covariance matrix is calculated using `np.cov`. It is calculated on the transposed matrix of the centered data `X.T` because `np.cov` expects features as rows and observations as columns.
#
# ```python
#         # eigenvalues, eigenvectors
#         self.eigenvalues, self.eigenvectors = np.linalg.eigh(cov)
# ```
# Eigenvalues and eigenvectors are computed using `np.linalg.eigh`, which computes the eigenvalues and eigenvectors of a symmetric matrix like the covariance matrix. `eigh` ensures that the eigenvalues are returned in ascending order.
#
# ```python
#         # sort eigenvectors
#         self.eigenvectors = self.eigenvectors.T
#         idxs = np.argsort(self.eigenvalues)[::-1]
#         self.eigenvalues = self.eigenvalues[idxs]
#         self.eigenvectors = self.eigenvectors[idxs]
# ```
# The eigenvectors are sorted based on the corresponding eigenvalues in descending order.
#
# ```python
#         # store first n self.eigenvectors
#         self.components = self.eigenvectors[0 : self.number_of_components]
# ```
# The first `n` eigenvectors, where `n` is defined by `number_of_components`, are stored as `components`.
#
# ```python
#         self.eigenfaces = self.components
# ```
# The `eigenfaces` are set equal to the `components`.
#
# ```python
#         return X, self.mean, self.eigenvalues, self.eigenvectors, self.eigenfaces
# ```
# The method returns the mean-centered data `X`, the mean vector, eigenvalues, eigenvectors, and eigenfaces.
#
# ```python
#     def transform(self, X):
#         # project data
#         X = X - self.mean
#         weights = (self.eigenfaces @ X.T)
#         return weights
# ```
# The `transform` method projects the data onto the eigenvectors (or eigenfaces) to obtain the weights.
#
# ```python
#     def getEigenFacesAndWeights(self, X, first_n_components):
#         X = X - self.mean
#         first_n_eigenfaces = self.eigenvectors[0 : first_n_components]
#         first_n_eigenfaces_weights = (first_n_eigenfaces @ X.T)
#         return first_n_eigenfaces, first_n_eigenfaces_weights
# ```
# The `getEigenFacesAndWeights` method returns the first `n` eigenfaces and their corresponding weights, where `n` is specified by `first_n_components`.
#
# ```python
# pca = principalComponentAnalysis(number_of_components=100)
# X_mean, mean, eigenvalues, eigenvectors, eigenfaces = pca.fit(X_train)
# ```
# An instance of the PCA class is created with `number_of_components=100`. The `fit` method is called on `X_train` to calculate the mean, eigenvalues, eigenvectors, and eigenfaces. The mean-centered data, mean vector, eigenvalues, eigenvectors, and eigenfaces are assigned to respective variables.

# %%
print("X_mean: ", end="")
print(X_mean)
print("mean: ", end="")
print(mean)
print("all-eigenvectos: ", end="")
print(eigenvectos)
print("eigenvalues: ", end="")
print(eigenvalues)
print("pc-eigenfaces: ", end="")
print(eigenfaces)
print()
print(eigenvectos.shape)
print(eigenvalues.shape)
print(eigenfaces.shape)
# Out:
# X_mean: [[ 12.4         14.50277778  13.13888889 ... -23.85277778 -27.87222222
#   -23.2       ]
#  [ 15.4         14.50277778  13.13888889 ... -27.85277778 -23.87222222
#   -23.2       ]
#  [ 19.4         20.50277778  14.13888889 ...  -0.85277778   0.12777778
#     0.8       ]
#  ...
#  [-45.6        -48.49722222 -50.86111111 ... -49.85277778 -45.87222222
#   -51.2       ]
#  [-48.6        -48.49722222 -43.86111111 ... -47.85277778 -47.87222222
#   -48.2       ]
#  [-45.6        -50.49722222 -48.86111111 ... -43.85277778 -44.87222222
#   -46.2       ]]
# mean: [85.6        85.49722222 85.86111111 ... 76.85277778 75.87222222
#  75.2       ]
# all-eigenvectos: [[ 0.00208788  0.00209089  0.00216653 ...  0.00703657  0.00646714
#    0.00757517]
#  [ 0.01481234  0.01463152  0.01474913 ... -0.0106319  -0.0101442
#   -0.0093778 ]
#  [-0.02040714 -0.02055669 -0.02040686 ... -0.01231229 -0.01270109
#   -0.01325887]
#  ...
#  [-0.         -0.25849487  0.4918164  ...  0.00184036  0.00753839
#   -0.00067083]
#  [ 0.         -0.30473197  0.05259228 ... -0.00169863  0.0137609
#    0.02013397]
#  [ 0.         -0.03926203  0.20078489 ...  0.02734166 -0.00515717
#   -0.00055191]]
# eigenvalues: [ 2.81505682e+06  2.05129667e+06  1.13013036e+06 ... -1.31529877e-09
#  -1.40878784e-09 -1.46539012e-09]
# pc-eigenfaces: [[ 2.08788303e-03  2.09088895e-03  2.16653066e-03 ...  7.03656532e-03
#    6.46714254e-03  7.57517245e-03]
#  [ 1.48123394e-02  1.46315209e-02  1.47491337e-02 ... -1.06318979e-02
#   -1.01441964e-02 -9.37780116e-03]
#  [-2.04071384e-02 -2.05566892e-02 -2.04068626e-02 ... -1.23122916e-02
#   -1.27010881e-02 -1.32588731e-02]
#  ...
#  [-2.53715494e-03  6.16032673e-04 -6.50127683e-04 ...  1.89908660e-02
#    1.14837668e-02  1.70984185e-02]
#  [-2.71128125e-03 -2.70014713e-03 -1.47276873e-03 ... -5.38875067e-04
#   -1.22832106e-03  1.48358669e-02]
#  [ 3.13357550e-04  2.06455629e-04  1.70801462e-03 ... -9.25702656e-03
#   -4.14460359e-03 -9.46173797e-05]]
#
# (10304, 10304)
# (10304,)
# (100, 10304)

# %%
# plot the eigen faces
# %matplotlib inline
import matplotlib.pyplot as plt

num_eigenfaces_to_plot = 100

# Reshape and plot the first 50 eigenfaces
fig, axes = plt.subplots(10, 10, figsize=(15, 10))

for i in range(num_eigenfaces_to_plot):
    row = i // 10
    col = i % 10
    eigenface = eigenvectos[i, :].reshape((112, 92))
    axes[row, col].imshow(eigenface, cmap='gray')
    axes[row, col].axis('off')

plt.show()

# %% [markdown]
# #### Implement Image Reconstruction from Eigenfaces

# %% [markdown]
# Explain your steps with comments and write a brief explanation of the method.

# %%
# def imageReconstruction(testFace, eigenFaces, meanFace):

    # your code here

    # return None

# Function to implement image reconstruction by taking arguements as necessary.
def imageReconstruction(query_image, mean, weights, eigenfaces, y_train):
    """
    Helper function to reconstruct images
    """
    query_weight = eigenfaces @ (query_image - mean.T).T
    reconstructed_face = (eigenfaces.T @ query_weight).T + mean.T
    # print((query_image - mean).shape)
    # print(reconstructed_face.shape)
    #  + mean.T
    euclidean_distance = np.linalg.norm(weights - query_weight, axis=0)
    # print("euclidean_distance ", end="")
    # print(euclidean_distance)
    best_match = np.argmin(euclidean_distance)
    # print("best_match ", end="")
    # print(best_match)
    print("Best match %s with Euclidean distance %f" % (y_train[best_match], euclidean_distance[best_match]))
    return reconstructed_face, y_train[best_match], euclidean_distance[best_match]

# %% [markdown]
# This code defines a function `imageReconstruction` which is meant to reconstruct images using eigenfaces. Here's a breakdown of the code:
#
# ```python
# def imageReconstruction(query_image, mean, weights, eigenfaces, y_train):
#     """
#     Helper function to reconstruct images
#     """
# ```
#
# This is the function definition. It takes five arguments:
# - `query_image`: The image to be reconstructed.
# - `mean`: The mean face.
# - `weights`: The weights obtained from the training data.
# - `eigenfaces`: The eigenfaces obtained from the training data.
# - `y_train`: Labels associated with the training data.
#
# ```python
#     query_weight = eigenfaces @ (query_image - mean.T).T
# ```
#
# This line calculates the weight of the query image using the dot product of `eigenfaces` and the normalized difference between `query_image` and `mean`. The `@` operator is used for matrix multiplication.
#
# ```python
#     reconstructed_face = (eigenfaces.T @ query_weight).T + mean.T
# ```
#
# This line reconstructs the face using the calculated weight. It first multiplies the transposed `eigenfaces` with `query_weight`, then adds the mean face. The `.T` is used to transpose matrices.
#
# ```python
#     euclidean_distance = np.linalg.norm(weights - query_weight, axis=0)
# ```
#
# This calculates the Euclidean distance between the weight of the query image and the weights of the training images. `np.linalg.norm` is used to calculate the Euclidean norm.
#
# ```python
#     best_match = np.argmin(euclidean_distance)
# ```
#
# This finds the index of the minimum value in the `euclidean_distance` array, which corresponds to the index of the best-matching image in the training set.
#
# ```python
#     print("Best match %s with Euclidean distance %f" % (y_train[best_match], euclidean_distance[best_match]))
# ```
#
# This line prints out the label of the best-matching image along with its Euclidean distance.
#
# ```python
#     return reconstructed_face, y_train[best_match], euclidean_distance[best_match]
# ```
#
# Finally, the function returns the reconstructed face, its label, and the Euclidean distance to the best-matching image.

# %%
# plot recontructions here
# %matplotlib inline
# Create a figure and subplots
fig, axes = plt.subplots(1, 1, figsize=(25, 1))

# Plot first row of images
# count = 0

face = mean.T.reshape((112, 92))
axes.imshow(face, cmap='gray')
axes.axis('off')

plt.show()

# %% [markdown]
# #### Visualisation
# Visualise the results for different number of factors(components = [3,5,10,20,30,40,50,100])
#
# **Note:** Ensure that the images are labelled appropriately.

# %%
# %matplotlib inline

# def displayNfactors():

#     # your code here

#     return None

# %% [markdown]
# #### Implement face recognition module based on the norm
# Explain your steps with comments and write a brief explanation of the method.
#
# *   Test the module and report accuracies based on the number of components taken for a range of value and plot them.
# *   Also plot the mean square error vs the number of eigenvectors taken and report your observations.
# *   For further empirical analysis, plot the semi-log variant of the error plot obtained above.

# %%
''' def getClass():
    """
    Arguments:
    1. Test image
    2. Eigenvectors
    3. Mean Eigen Face
    4. Training Set(X_train,y_train)

    The function must return the following:
    1. image with smallest error
    2. error value
    3. prediction class
    """

    # your code here

    # return None
'''

def getClass(no_of_components_list):
    # no_of_components_list = [5,10,50,100,1000,10304] # maximum no of components = 10304
    # no_of_components_list = [5,10]
    components_res_dict = {}
    reconstructed_faces_res_dict = {}
    for n_components in no_of_components_list:
        print("no_of_components: " + str(n_components))
        first_n_eigenfaces, first_n_weights = pca.getEigenFacesAndWeights(X_train, n_components)

        components_res_list = []
        reconstructed_faces = []
        for index in range(len(X_test)):
            test_image = X_test[index]
            print(test_image)
            test_image_label = y_test[index]
            print(test_image_label)
            test_image_flatten = test_image.reshape(1,-1)
            # print(index, imageReconstruction(test_image_flatten, mean, first_n_weights, first_n_eigenfaces, y_train))
            reconstructed_face, best_match_label, best_match_euclidean_dist = imageReconstruction(test_image_flatten, mean, first_n_weights, first_n_eigenfaces, y_train)
            reconstructed_faces.append(reconstructed_face)
        #   print(reconstructed_face.shape)
            best_match_label_list = best_match_label.split('/')
            test_image_label_list = test_image_label.split('/')
            if(best_match_label_list[2] == test_image_label_list[2]):
                components_res_list.append([test_image_label, best_match_label, True, best_match_euclidean_dist, np.emath.log(best_match_euclidean_dist)])
            else:
                components_res_list.append([test_image_label, best_match_label, False, best_match_euclidean_dist, np.emath.log(best_match_euclidean_dist)])
            # plot recontructions here
        #   plt.imshow(test_image_flatten.reshape(112, 92),cmap="gray")
        #   plt.imshow(query_weight.reshape(112, 92),cmap="gray")
        #   plt.imshow(att_faces_dict[best_match_label],cmap="gray")
        components_res_dict[n_components] = components_res_list
        reconstructed_faces_res_dict[n_components] = reconstructed_faces
    return components_res_dict, reconstructed_faces_res_dict

# %% [markdown]
# This code defines a function `getClass` which seems to be related to some classification task, particularly involving facial recognition or image classification. Let's break down the code:
#
# ```python
# def getClass(no_of_components_list):
# ```
# This function takes a list `no_of_components_list` as input. This list presumably contains the number of components to be used for some dimensionality reduction technique like Principal Component Analysis (PCA).
#
# ```python
# components_res_dict = {}
# reconstructed_faces_res_dict = {}
# ```
# Two dictionaries are initialized to store results. `components_res_dict` will store classification results, and `reconstructed_faces_res_dict` will store the reconstructed faces.
#
# ```python
# for n_components in no_of_components_list:
# ```
# This loop iterates over the list of numbers of components.
#
# ```python
# first_n_eigenfaces, first_n_weights = pca.getEigenFacesAndWeights(X_train, n_components)
# ```
# It seems to be calling a function `getEigenFacesAndWeights` from a PCA (Principal Component Analysis) module or class (`pca`). This function likely computes the first `n_components` eigenfaces and their corresponding weights using some training data `X_train`.
#
# ```python
# for index in range(len(X_test)):
# ```
# Another loop iterates over the test data `X_test`.
#
# ```python
# test_image = X_test[index]
# test_image_label = y_test[index]
# ```
# It retrieves a test image and its corresponding label.
#
# ```python
# reconstructed_face, best_match_label, best_match_euclidean_dist = imageReconstruction(test_image_flatten, mean, first_n_weights, first_n_eigenfaces, y_train)
# ```
# It calls the `imageReconstruction` function to reconstruct the test image using the eigenfaces and weights computed earlier.
#
# ```python
# best_match_label_list = best_match_label.split('/')
# test_image_label_list = test_image_label.split('/')
# ```
# It seems to be splitting the labels, possibly to compare certain components. The specifics of this comparison depend on the structure of the labels, which might indicate different classes or categories.
#
# ```python
# if(best_match_label_list[2] == test_image_label_list[2]):
# ```
# This compares some components of the labels, and based on the result, it appends information about the classification result to `components_res_list`.
#
# ```python
# components_res_dict[n_components] = components_res_list
# reconstructed_faces_res_dict[n_components] = reconstructed_faces
# ```
# Finally, the classification results and reconstructed faces are stored in their respective dictionaries.
#
# ```python
# return components_res_dict, reconstructed_faces_res_dict
# ```
# The function returns these dictionaries containing the results.

# %% [markdown]
# Iterate through all the images in the test data and test the accuracy by taking different number of components

# %%
components_list = [3,5,10,20,30,40,50,100]
mse = []

# for numComponents in components:
    # your code here
components_res_dict, reconstructed_faces_res_dict = getClass(components_list)
# Out:
# no_of_components: 3
# [103 104 105 ...  76  76  75]
# ./ATnT/s29/5.pgm
# Best match ./ATnT/s29/6.pgm with Euclidean distance 340.041290
# [56 61 54 ... 40 43 45]
# ./ATnT/s17/1.pgm
# Best match ./ATnT/s16/3.pgm with Euclidean distance 395.425480
# [ 53  58  53 ... 195 122  76]
# ./ATnT/s22/8.pgm
# Best match ./ATnT/s22/1.pgm with Euclidean distance 164.628700
# [ 50  49  50 ... 159 111 117]
# ./ATnT/s14/1.pgm
# Best match ./ATnT/s14/3.pgm with Euclidean distance 134.427711
# [124 125 125 ...  84  89  85]
# ./ATnT/s5/10.pgm
# Best match ./ATnT/s18/10.pgm with Euclidean distance 271.331833
# [111 107 109 ...  65  68  65]
# ./ATnT/s30/1.pgm
# Best match ./ATnT/s30/10.pgm with Euclidean distance 105.221559
# [121 120 120 ...  79  76  78]
# ./ATnT/s15/2.pgm
# Best match ./ATnT/s15/10.pgm with Euclidean distance 200.371630
# [34 38 36 ... 55 58 55]
# ./ATnT/s24/3.pgm
# Best match ./ATnT/s24/8.pgm with Euclidean distance 248.062920
# [64 76 80 ... 35 37 39]
# ./ATnT/s1/5.pgm
# Best match ./ATnT/s1/4.pgm with Euclidean distance 588.663691
# [34 35 35 ... 31 24 24]
# ./ATnT/s2/6.pgm
# Best match ./ATnT/s2/4.pgm with Euclidean distance 327.675033
# [ 54  49  56 ... 154 154 162]
# ./ATnT/s33/9.pgm
# Best match ./ATnT/s33/8.pgm with Euclidean distance 152.266263
# [ 91  83  70 ... 171 188 190]
# ./ATnT/s35/5.pgm
# Best match ./ATnT/s26/6.pgm with Euclidean distance 259.655037
# [119 121 119 ...  82  78  80]
# ./ATnT/s4/4.pgm
# Best match ./ATnT/s4/5.pgm with Euclidean distance 152.393970
# [ 95 101  99 ...  40  42  53]
# ./ATnT/s12/6.pgm
# Best match ./ATnT/s12/8.pgm with Euclidean distance 280.159928
# [54 51 49 ... 61 59 63]
# ./ATnT/s7/7.pgm
# Best match ./ATnT/s7/3.pgm with Euclidean distance 147.115773
# [ 28  25  27 ... 187 187 190]
# ./ATnT/s34/1.pgm
# Best match ./ATnT/s34/2.pgm with Euclidean distance 179.849611
# [131 125 126 ...  89  93  91]
# ./ATnT/s40/3.pgm
# Best match ./ATnT/s40/2.pgm with Euclidean distance 295.666788
# [100 110 107 ...  64  71  59]
# ./ATnT/s9/2.pgm
# Best match ./ATnT/s9/3.pgm with Euclidean distance 263.614174
# [63 60 63 ... 63 69 58]
# ./ATnT/s16/8.pgm
# Best match ./ATnT/s16/9.pgm with Euclidean distance 384.228255
# [45 49 47 ... 40 30 44]
# ./ATnT/s11/6.pgm
# Best match ./ATnT/s11/10.pgm with Euclidean distance 286.079598
# [124 124 123 ...  99 102  95]
# ./ATnT/s25/4.pgm
# Best match ./ATnT/s26/5.pgm with Euclidean distance 191.926443
# [51 41 56 ... 43 49 36]
# ./ATnT/s19/2.pgm
# Best match ./ATnT/s19/7.pgm with Euclidean distance 243.717283
# [52 47 51 ... 30 34 42]
# ./ATnT/s37/2.pgm
# Best match ./ATnT/s37/6.pgm with Euclidean distance 130.267790
# [63 67 65 ... 54 61 69]
# ./ATnT/s36/1.pgm
# Best match ./ATnT/s36/5.pgm with Euclidean distance 346.679473
# [116 116 117 ...  19  24  16]
# ./ATnT/s20/4.pgm
# Best match ./ATnT/s20/6.pgm with Euclidean distance 222.895394
# [118 123 120 ...  79  81  84]
# ./ATnT/s18/6.pgm
# Best match ./ATnT/s18/7.pgm with Euclidean distance 185.605579
# [105 110 106 ...  18  27  22]
# ./ATnT/s13/10.pgm
# Best match ./ATnT/s13/5.pgm with Euclidean distance 79.593894
# [155 154 153 ... 113 110 111]
# ./ATnT/s6/8.pgm
# Best match ./ATnT/s6/6.pgm with Euclidean distance 41.456766
# [126 130 131 ...  43  51  48]
# ./ATnT/s8/1.pgm
# Best match ./ATnT/s8/4.pgm with Euclidean distance 207.988086
# [39 43 39 ... 24 24 23]
# ./ATnT/s27/8.pgm
# Best match ./ATnT/s27/6.pgm with Euclidean distance 130.067376
# [104 106 105 ... 148 155 168]
# ./ATnT/s21/7.pgm
# Best match ./ATnT/s38/5.pgm with Euclidean distance 196.001244
# [ 96  94  98 ... 131 136 152]
# ./ATnT/s31/8.pgm
# Best match ./ATnT/s21/9.pgm with Euclidean distance 367.455291
# [116 119 117 ...  60  54  64]
# ./ATnT/s23/5.pgm
# Best match ./ATnT/s23/3.pgm with Euclidean distance 83.899974
# [101 106 102 ...  46  50  45]
# ./ATnT/s3/3.pgm
# Best match ./ATnT/s3/1.pgm with Euclidean distance 292.640809
# [109 105 112 ...  55  50  51]
# ./ATnT/s26/1.pgm
# Best match ./ATnT/s35/9.pgm with Euclidean distance 242.679224
# [108 112 109 ...  73  64  69]
# ./ATnT/s38/9.pgm
# Best match ./ATnT/s9/4.pgm with Euclidean distance 226.779801
# [48 48 55 ... 88 93 99]
# ./ATnT/s28/5.pgm
# Best match ./ATnT/s28/7.pgm with Euclidean distance 122.909676
# [135 133 136 ...  18  21  24]
# ./ATnT/s10/8.pgm
# Best match ./ATnT/s10/7.pgm with Euclidean distance 401.902244
# [ 97  94  92 ... 144 143 129]
# ./ATnT/s39/6.pgm
# Best match ./ATnT/s39/2.pgm with Euclidean distance 276.768905
# [38 33 43 ... 26 28 23]
# ./ATnT/s32/3.pgm
# Best match ./ATnT/s32/2.pgm with Euclidean distance 257.070309
# no_of_components: 5
# [103 104 105 ...  76  76  75]
# ./ATnT/s29/5.pgm
# Best match ./ATnT/s29/6.pgm with Euclidean distance 352.264927
# [56 61 54 ... 40 43 45]
# ./ATnT/s17/1.pgm
# Best match ./ATnT/s17/5.pgm with Euclidean distance 507.035040
# [ 53  58  53 ... 195 122  76]
# ./ATnT/s22/8.pgm
# Best match ./ATnT/s22/9.pgm with Euclidean distance 268.387957
# [ 50  49  50 ... 159 111 117]
# ./ATnT/s14/1.pgm
# Best match ./ATnT/s14/3.pgm with Euclidean distance 226.913821
# [124 125 125 ...  84  89  85]
# ./ATnT/s5/10.pgm
# Best match ./ATnT/s18/10.pgm with Euclidean distance 476.735385
# [111 107 109 ...  65  68  65]
# ./ATnT/s30/1.pgm
# Best match ./ATnT/s30/6.pgm with Euclidean distance 371.564920
# [121 120 120 ...  79  76  78]
# ./ATnT/s15/2.pgm
# Best match ./ATnT/s15/10.pgm with Euclidean distance 256.794973
# [34 38 36 ... 55 58 55]
# ./ATnT/s24/3.pgm
# Best match ./ATnT/s24/10.pgm with Euclidean distance 590.357404
# [64 76 80 ... 35 37 39]
# ./ATnT/s1/5.pgm
# Best match ./ATnT/s1/4.pgm with Euclidean distance 908.999489
# [34 35 35 ... 31 24 24]
# ./ATnT/s2/6.pgm
# Best match ./ATnT/s2/2.pgm with Euclidean distance 547.404102
# [ 54  49  56 ... 154 154 162]
# ./ATnT/s33/9.pgm
# Best match ./ATnT/s33/5.pgm with Euclidean distance 214.398456
# [ 91  83  70 ... 171 188 190]
# ./ATnT/s35/5.pgm
# Best match ./ATnT/s35
# [48 48 55 ... 88 93 99]
# ./ATnT/s28/5.pgm
# Best match ./ATnT/s28/2.pgm with Euclidean distance 777.503804
# [135 133 136 ...  18  21  24]
# ./ATnT/s10/8.pgm
# Best match ./ATnT/s10/2.pgm with Euclidean distance 1374.876100
# [ 97  94  92 ... 144 143 129]
# ./ATnT/s39/6.pgm
# Best match ./ATnT/s39/10.pgm with Euclidean distance 1224.208365
# [38 33 43 ... 26 28 23]
# ./ATnT/s32/3.pgm
# Best match ./ATnT/s32/2.pgm with Euclidean distance 644.359965
# no_of_components: 30
# [103 104 105 ...  76  76  75]
# ./ATnT/s29/5.pgm
# Best match ./ATnT/s29/6.pgm with Euclidean distance 650.242692
# [56 61 54 ... 40 43 45]
# ./ATnT/s17/1.pgm
# Best match ./ATnT/s17/5.pgm with Euclidean distance 861.959910
# [ 53  58  53 ... 195 122  76]
# ./ATnT/s22/8.pgm
# Best match ./ATnT/s22/1.pgm with Euclidean distance 786.429962
# [ 50  49  50 ... 159 111 117]
# ./ATnT/s14/1.pgm
# Best match ./ATnT/s14/4.pgm with Euclidean distance 1081.797355
# [124 125 125 ...  84  89  85]
# ./ATnT/s5/10.pgm
# Best match ./ATnT/s40/5.pgm with Euclidean distance 1647.012361
# [111 107 109 ...  65  68  65]
# ./ATnT/s30/1.pgm
# Best match ./ATnT/s30/10.pgm with Euclidean distance 915.454938
# [121 120 120 ...  79  76  78]
# ./ATnT/s15/2.pgm
# Best match ./ATnT/s15/5.pgm with Euclidean distance 651.802772
# [34 38 36 ... 55 58 55]
# ./ATnT/s24/3.pgm
# Best match ./ATnT/s24/10.pgm with Euclidean distance 1420.343150
# [64 76 80 ... 35 37 39]
# ./ATnT/s1/5.pgm
# Best match ./ATnT/s1/9.pgm with Euclidean distance 2541.633154
# [34 35 35 ... 31 24 24]
# ./ATnT/s2/6.pgm
# Best match ./ATnT/s2/2.pgm with Euclidean distance 1243.619746
# [ 54  49  56 ... 154 154 162]
# ./ATnT/s33/9.pgm
# Best match ./ATnT/s33/5.pgm with Euclidean distance 1061.536750
# [ 91  83  70 ... 171 188 190]
# ./ATnT/s35/5.pgm
# Best match ./ATnT/s35/9.pgm with Euclidean distance 2014.569402
# [119 121 119 ...  82  78  80]
# ./ATnT/s4/4.pgm
# Best match ./ATnT/s4/7.pgm with Euclidean distance 964.210630
# [ 95 101  99 ...  40  42  53]
# ./ATnT/s12/6.pgm
# Best match ./ATnT/s12/1.pgm with Euclidean distance 1586.431813
# [54 51 49 ... 61 59 63]
# ./ATnT/s7/7.pgm
# Best match ./ATnT/s7/3.pgm with Euclidean distance 926.446379
# [ 28  25  27 ... 187 187 190]
# ./ATnT/s34/1.pgm
# Best match ./ATnT/s34/2.pgm with Euclidean distance 750.433338
# [131 125 126 ...  89  93  91]
# ./ATnT/s40/3.pgm
# Best match ./ATnT/s40/2.pgm with Euclidean distance 1303.084794
# [100 110 107 ...  64  71  59]
# ./ATnT/s9/2.pgm
# Best match ./ATnT/s9/3.pgm with Euclidean distance 1283.430309
# [63 60 63 ... 63 69 58]
# ./ATnT/s16/8.pgm
# Best match ./ATnT/s16/9.pgm with Euclidean distance 2082.785589
# [45 49 47 ... 40 30 44]
# ./ATnT/s11/6.pgm
# Best match ./ATnT/s11/3.pgm with Euclidean distance 1592.406204
# [124 124 123 ...  99 102  95]
# ./ATnT/s25/4.pgm
# Best match ./ATnT/s25/5.pgm with Euclidean distance 1447.539450
# [51 41 56 ... 43 49 36]
# ./ATnT/s19/2.pgm
# Best match ./ATnT/s19/1.pgm with Euclidean distance 738.794844
# [52 47 51 ... 30 34 42]
# ./ATnT/s37/2.pgm
# Best match ./ATnT/s37/5.pgm with Euclidean distance 717.298949
# [63 67 65 ... 54 61 69]
# ./ATnT/s36/1.pgm
# Best match ./ATnT/s36/5.pgm with Euclidean distance 1255.963874
# [116 116 117 ...  19  24  16]
# ./ATnT/s20/4.pgm
# Best match ./ATnT/s20/6.pgm with Euclidean distance 575.113271
# [118 123 120 ...  79  81  84]
# ./ATnT/s18/6.pgm
# Best match ./ATnT/s18/8.pgm with Euclidean distance 1290.272535
# [105 110 106 ...  18  27  22]
# ./ATnT/s13/10.pgm
# Best match ./ATnT/s13/5.pgm with Euclidean distance 410.560534
# [155 154 153 ... 113 110 111]
# ./ATnT/s6/8.pgm
# Best match ./ATnT/s6/6.pgm with Euclidean distance 1100.422116
# [126 130 131 ...  43  51  48]
# ./ATnT/s8/1.pgm
# Best match ./ATnT/s8/2.pgm with Euclidean distance 926.302503
# [39 43 39 ... 24 24 23]
# ./ATnT/s27/8.pgm
# Best match ./ATnT/s27/9.pgm with Euclidean distance 875.512826
# [104 106 105 ... 148 155 168]
# ./ATnT/s21/7.pgm
# Best match ./ATnT/s21/10.pgm with Euclidean distance 1199.618413
# [ 96  94  98 ... 131 136 152]
# ./ATnT/s31/8.pgm
# Best match ./ATnT/s31/1.pgm with Euclidean distance 960.556036
# [116 119 117 ...  60  54  64]
# ./ATnT/s23/5.pgm
# Best match ./ATnT/s23/3.pgm with Euclidean distance 862.747339
# [101 106 102 ...  46  50  45]
# ./ATnT/s3/3.pgm
# Best match ./ATnT/s3/2.pgm with Euclidean distance 1054.823226
# [109 105 112 ...  55  50  51]
# ./ATnT/s26/1.pgm
# Best match ./ATnT/s26/3.pgm with Euclidean distance 1473.058950
# [108 112 109 ...  73  64  69]
# ./ATnT/s38/9.pgm
# Best match ./ATnT/s38/1.pgm with Euclidean distance 1284.101752
# [48 48 55 ... 88 93 99]
# ./ATnT/s28/5.pgm
# Best match ./ATnT/s28/2.pgm with Euclidean distance 904.610821
# [135 133 136 ...  18  21  24]
# ./ATnT/s10/8.pgm
# Best match ./ATnT/s10/2.pgm with Euclidean distance 1464.334972
# [ 97  94  92 ... 144 143 129]
# ./ATnT/s39/6.pgm
# Best match ./ATnT/s39/10.pgm with Euclidean distance 1366.963322
# [38 33 43 ... 26 28 23]
# ./ATnT/s32/3.pgm
# Best match ./ATnT/s32/2.pgm with Euclidean distance 940.834408
# no_of_components: 40
# [103 104 105 ...  76  76  75]
# ./ATnT/s29/5.pgm
# Best match ./ATnT/s29/6.pgm with Euclidean distance 713.446046
# [56 61 54 ... 40 43 45]
# ./ATnT/s17/1.pgm
# Best match ./ATnT/s17/5.pgm with Euclidean distance 937.470949
# [ 53  58  53 ... 195 122  76]
# ./ATnT/s22/8.pgm
# Best match ./ATnT/s22/3.pgm with Euclidean distance 857.368523
# [ 50  49  50 ... 159 111 117]
# ./ATnT/s14/1.pgm
# Best match ./ATnT/s14/4.pgm with Euclidean distance 1205.995204
# [124 125 125 ...  84  89  85]
# ./ATnT/s5/10.pgm
# Best match ./ATnT/s40/5.pgm with Euclidean distance 1760.164545
# [111 107 109 ...  65  68  65]
# ./ATnT/s30/1.pgm
# Best match ./ATnT/s30/10.pgm with Euclidean distance 1017.156588
# [121 120 120 ...  79  76  78]
# ./ATnT/s15/2.pgm
# Best match ./ATnT/s15/10.pgm with Euclidean distance 778.701689
# [34 38 36 ... 55 58 55]
# ./ATnT/s24/3.pgm
# Best match ./ATnT/s24/10.pgm with Euclidean distance 1505.896416
# [64 76 80 ... 35 37 39]
# ./ATnT/s1/5.pgm
# Best match ./ATnT/s1/10.pgm with Euclidean distance 2634.589953
# [34 35 35 ... 31 24 24]
# ./ATnT/s2/6.pgm
# Best match ./ATnT/s2/2.pgm with Euclidean distance 1345.389639
# [ 54  49  56 ... 154 154 162]
# ./ATnT/s33/9.pgm
# Best match ./ATnT/s33/5.pgm with Euclidean distance 1156.379101
# [ 91  83  70 ... 171 188 190]
# ./ATnT/s35/5.pgm
# Best match ./ATnT/s35/9.pgm with Euclidean distance 2135.959942
# [119 121 119 ...  82  78  80]
# ./ATnT/s4/4.pgm
# Best match ./ATnT/s4/7.pgm with Euclidean distance 1029.076660
# [ 95 101  99 ...  40  42  53]
# ./ATnT/s12/6.pgm
# Best match ./ATnT/s12/1.pgm with Euclidean distance 1744.239606
# [54 51 49 ... 61 59 63]
# ./ATnT/s7/7.pgm
# Best match ./ATnT/s7/9.pgm with Euclidean distance 999.374829
# [ 28  25  27 ... 187 187 190]
# ./ATnT/s34/1.pgm
# Best match ./ATnT/s34/2.pgm with Euclidean distance 931.724737
# [131 125 126 ...  89  93  91]
# ./ATnT/s40/3.pgm
# Best match ./ATnT/s40/2.pgm with Euclidean distance 1403.595545
# [100 110 107 ...  64  71  59]
# ./ATnT/s9/2.pgm
# Best match ./ATnT/s9/3.pgm with Euclidean distance 1405.722373
# [63 60 63 ... 63 69 58]
# ./ATnT/s16/8.pgm
# Best match ./ATnT/s16/9.pgm with Euclidean distance 2207.475272
# [45 49 47 ... 40 30 44]
# ./ATnT/s11/6.pgm
# Best match ./ATnT/s11/1.pgm with Euclidean distance 1734.228771
# [124 124 123 ...  99 102  95]
# ./ATnT/s25/4.pgm
# Best match ./ATnT/s25/5.pgm with Euclidean distance 1511.364408
# [51 41 56 ... 43 49 36]
# ./ATnT/s19/2.pgm
# Best match ./ATnT/s19/1.pgm with Euclidean distance 796.447747
# [52 47 51 ... 30 34 42]
# ./ATnT/s37/2.pgm
# Best match ./ATnT/s37/5.pgm with Euclidean distance 827.726329
# [63 67 65 ... 54 61 69]
# ./ATnT/s36/1.pgm
# Best match ./ATnT/s36/5.pgm with Euclidean distance 1565.637273
# [116 116 117 ...  19  24  16]
# ./ATnT/s20/4.pgm
# Best match ./ATnT/s20/6.pgm with Euclidean distance 659.681358
# [118 123 120 ...  79  81  84]
# ./ATnT/s18/6.pgm
# Best match ./ATnT/s18/8.pgm with Euclidean distance 1322.620457
# [105 110 106 ...  18  27  22]
# ./ATnT/s13/10.pgm
# Best match ./ATnT/s13/5.pgm with Euclidean distance 485.059179
# [155 154 153 ... 113 110 111]
# ./ATnT/s6/8.pgm
# Best match ./ATnT/s6/6.pgm with Euclidean distance 1174.556238
# [126 130 131 ...  43  51  48]
# ./ATnT/s8/1.pgm
# Best match ./ATnT/s8/2.pgm with Euclidean distance 1011.564248
# [39 43 39 ... 24 24 23]
# ./ATnT/s27/8.pgm
# Best match ./ATnT/s27/9.pgm with Euclidean distance 916.352801
# [104 106 105 ... 148 155 168]
# ./ATnT/s21/7.pgm
# Best match ./ATnT/s21/10.pgm with Euclidean distance 1354.413741
# [ 96  94  98 ... 131 136 152]
# ./ATnT/s31/8.pgm
# Best match ./ATnT/s31/1.pgm with Euclidean distance 1049.068757
# [116 119 117 ...  60  54  64]
# ./ATnT/s23/5.pgm
# Best match ./ATnT/s23/3.pgm with Euclidean distance 899.005206
# [101 106 102 ...  46  50  45]
# ./ATnT/s3/3.pgm
# Best match ./ATnT/s3/2.pgm with Euclidean distance 1136.115283
# [109 105 112 ...  55  50  51]
# ./ATnT/s26/1.pgm
# Best match ./ATnT/s26/3.pgm with Euclidean distance 1645.192735
# [108 112 109 ...  73  64  69]
# ./ATnT/s38/9.pgm
# Best match ./ATnT/s38/1.pgm with Euclidean distance 1479.619059
# [48 48 55 ... 88 93 99]
# ./ATnT/s28/5.pgm
# Best match ./ATnT/s28/2.pgm with Euclidean distance 959.650688
# [135 133 136 ...  18  21  24]
# ./ATnT/s10/8.pgm
# Best match ./ATnT/s10/2.pgm with Euclidean distance 1546.499637
# [ 97  94  92 ... 144 143 129]
# ./ATnT/s39/6.pgm
# Best match ./ATnT/s39/10.pgm with Euclidean distance 1476.227105
# [38 33 43 ... 26 28 23]
# ./ATnT/s32/3.pgm
# Best match ./ATnT/s32/2.pgm with Euclidean distance 1104.272864
# no_of_components: 50
# [103 104 105 ...  76  76  75]
# ./ATnT/s29/5.pgm
# Best match ./ATnT/s29/6.pgm with Euclidean distance 802.586416
# [56 61 54 ... 40 43 45]
# ./ATnT/s17/1.pgm
# Best match ./ATnT/s17/5.pgm with Euclidean distance 1001.802032
# [ 53  58  53 ... 195 122  76]
# ./ATnT/s22/8.pgm
# Best match ./ATnT/s22/3.pgm with Euclidean distance 954.451048
# [ 50  49  50 ... 159 111 117]
# ./ATnT/s14/1.pgm
# Best match ./ATnT/s14/4.pgm with Euclidean distance 1362.412533
# [124 125 125 ...  84  89  85]
# ./ATnT/s5/10.pgm
# Best match ./ATnT/s40/5.pgm with Euclidean distance 1844.262027
# [111 107 109 ...  65  68  65]
# ./ATnT/s30/1.pgm
# Best match ./ATnT/s30/10.pgm with Euclidean distance 1054.108983
# [121 120 120 ...  79  76  78]
# ./ATnT/s15/2.pgm
# Best match ./ATnT/s15/5.pgm with Euclidean distance 838.708253
# [34 38 36 ... 55 58 55]
# ./ATnT/s24/3.pgm
# Best match ./ATnT/s24/10.pgm with Euclidean distance 1708.276322
# [64 76 80 ... 35 37 39]
# ./ATnT/s1/5.pgm
# Best match ./ATnT/s1/10.pgm with Euclidean distance 2716.644177
# [34 35 35 ... 31 24 24]
# ./ATnT/s2/6.pgm
# Best match ./ATnT/s2/2.pgm with Euclidean distance 1419.373199
# [ 54  49  56 ... 154 154 162]
# ./ATnT/s33/9.pgm
# Best match ./ATnT/s33/5.pgm with Euclidean distance 1240.823240
# [ 91  83  70 ... 171 188 190]
# ./ATnT/s35/5.pgm
# Best match ./ATnT/s35/10.pgm with Euclidean distance 2226.292348
# [119 121 119 ...  82  78  80]
# ./ATnT/s4/4.pgm
# Best match ./ATnT/s4/7.pgm with Euclidean distance 1052.840672
# [ 95 101  99 ...  40  42  53]
# ./ATnT/s12/6.pgm
# Best match ./ATnT/s12/1.pgm with Euclidean distance 1856.281734
# [54 51 49 ... 61 59 63]
# ./ATnT/s7/7.pgm
# Best match ./ATnT/s7/9.pgm with Euclidean distance 1062.547282
# [ 28  25  27 ... 187 187 190]
# ./ATnT/s34/1.pgm
# Best match ./ATnT/s34/2.pgm with Euclidean distance 1131.988662
# [131 125 126 ...  89  93  91]
# ./ATnT/s40/3.pgm
# Best match ./ATnT/s40/2.pgm with Euclidean distance 1467.176139
# [100 110 107 ...  64  71  59]
# ./ATnT/s9/2.pgm
# Best match ./ATnT/s9/3.pgm with Euclidean distance 1472.112701
# [63 60 63 ... 63 69 58]
# ./ATnT/s16/8.pgm
# Best match ./ATnT/s16/9.pgm with Euclidean distance 2303.358965
# [45 49 47 ... 40 30 44]
# ./ATnT/s11/6.pgm
# Best match ./ATnT/s11/1.pgm with Euclidean distance 1848.233921
# [124 124 123 ...  99 102  95]
# ./ATnT/s25/4.pgm
# Best match ./ATnT/s25/5.pgm with Euclidean distance 1640.725824
# [51 41 56 ... 43 49 36]
# ./ATnT/s19/2.pgm
# Best match ./ATnT/s19/1.pgm with Euclidean distance 853.776804
# [52 47 51 ... 30 34 42]
# ./ATnT/s37/2.pgm
# Best match ./ATnT/s37/5.pgm with Euclidean distance 895.110656
# [63 67 65 ... 54 61 69]
# ./ATnT/s36/1.pgm
# Best match ./ATnT/s36/5.pgm with Euclidean distance 1670.042386
# [116 116 117 ...  19  24  16]
# ./ATnT/s20/4.pgm
# Best match ./ATnT/s20/6.pgm with Euclidean distance 700.690616
# [118 123 120 ...  79  81  84]
# ./ATnT/s18/6.pgm
# Best match ./ATnT/s18/8.pgm with Euclidean distance 1355.250008
# [105 110 106 ...  18  27  22]
# ./ATnT/s13/10.pgm
# Best match ./ATnT/s13/5.pgm with Euclidean distance 614.951140
# [155 154 153 ... 113 110 111]
# ./ATnT/s6/8.pgm
# Best match ./ATnT/s6/6.pgm with Euclidean distance 1216.854474
# [126 130 131 ...  43  51  48]
# ./ATnT/s8/1.pgm
# Best match ./ATnT/s8/2.pgm with Euclidean distance 1080.129199
# [39 43 39 ... 24 24 23]
# ./ATnT/s27/8.pgm
# Best match ./ATnT/s27/9.pgm with Euclidean distance 984.528751
# [104 106 105 ... 148 155 168]
# ./ATnT/s21/7.pgm
# Best match ./ATnT/s21/10.pgm with Euclidean distance 1433.749944
# [ 96  94  98 ... 131 136 152]
# ./ATnT/s31/8.pgm
# Best match ./ATnT/s31/1.pgm with Euclidean distance 1082.099536
# [116 119 117 ...  60  54  64]
# ./ATnT/s23/5.pgm
# Best match ./ATnT/s23/3.pgm with Euclidean distance 946.620933
# [101 106 102 ...  46  50  45]
# ./ATnT/s3/3.pgm
# Best match ./ATnT/s3/2.pgm with Euclidean distance 1214.915604
# [109 105 112 ...  55  50  51]
# ./ATnT/s26/1.pgm
# Best match ./ATnT/s26/6.pgm with Euclidean distance 1693.434283
# [108 112 109 ...  73  64  69]
# ./ATnT/s38/9.pgm
# Best match ./ATnT/s38/1.pgm with Euclidean distance 1608.741816
# [48 48 55 ... 88 93 99]
# ./ATnT/s28/5.pgm
# Best match ./ATnT/s28/2.pgm with Euclidean distance 1100.104797
# [135 133 136 ...  18  21  24]
# ./ATnT/s10/8.pgm
# Best match ./ATnT/s10/2.pgm with Euclidean distance 1631.613156
# [ 97  94  92 ... 144 143 129]
# ./ATnT/s39/6.pgm
# Best match ./ATnT/s39/10.pgm with Euclidean distance 1540.095436
# [38 33 43 ... 26 28 23]
# ./ATnT/s32/3.pgm
# Best match ./ATnT/s32/2.pgm with Euclidean distance 1282.263330
# no_of_components: 100
# [103 104 105 ...  76  76  75]
# ./ATnT/s29/5.pgm
# Best match ./ATnT/s29/6.pgm with Euclidean distance 1040.569098
# [56 61 54 ... 40 43 45]
# ./ATnT/s17/1.pgm
# Best match ./ATnT/s17/5.pgm with Euclidean distance 1225.679074
# [ 53  58  53 ... 195 122  76]
# ./ATnT/s22/8.pgm
# Best match ./ATnT/s22/3.pgm with Euclidean distance 1330.670671
# [ 50  49  50 ... 159 111 117]
# ./ATnT/s14/1.pgm
# Best match ./ATnT/s14/4.pgm with Euclidean distance 1772.744451
# [124 125 125 ...  84  89  85]
# ./ATnT/s5/10.pgm
# Best match ./ATnT/s40/5.pgm with Euclidean distance 2055.131062
# [111 107 109 ...  65  68  65]
# ./ATnT/s30/1.pgm
# Best match ./ATnT/s30/10.pgm with Euclidean distance 1243.562981
# [121 120 120 ...  79  76  78]
# ./ATnT/s15/2.pgm
# Best match ./ATnT/s15/5.pgm with Euclidean distance 1213.656783
# [34 38 36 ... 55 58 55]
# ./ATnT/s24/3.pgm
# Best match ./ATnT/s24/9.pgm with Euclidean distance 2082.214709
# [64 76 80 ... 35 37 39]
# ./ATnT/s1/5.pgm
# Best match ./ATnT/s1/10.pgm with Euclidean distance 3050.442184
# [34 35 35 ... 31 24 24]
# ./ATnT/s2/6.pgm
# Best match ./ATnT/s2/2.pgm with Euclidean distance 1774.737556
# [ 54  49  56 ... 154 154 162]
# ./ATnT/s33/9.pgm
# Best match ./ATnT/s33/5.pgm with Euclidean distance 1739.922872
# [ 91  83  70 ... 171 188 190]
# ./ATnT/s35/5.pgm
# Best match ./ATnT/s35/10.pgm with Euclidean distance 2545.248583
# [119 121 119 ...  82  78  80]
# ./ATnT/s4/4.pgm
# Best match ./ATnT/s4/7.pgm with Euclidean distance 1255.383866
# [ 95 101  99 ...  40  42  53]
# ./ATnT/s12/6.pgm
# Best match ./ATnT/s12/1.pgm with Euclidean distance 2154.862837
# [54 51 49 ... 61 59 63]
# ./ATnT/s7/7.pgm
# Best match ./ATnT/s7/3.pgm with Euclidean distance 1375.834702
# [ 28  25  27 ... 187 187 190]
# ./ATnT/s34/1.pgm
# Best match ./ATnT/s34/6.pgm with Euclidean distance 1473.337448
# [131 125 126 ...  89  93  91]
# ./ATnT/s40/3.pgm
# Best match ./ATnT/s40/2.pgm with Euclidean distance 1730.800444
# [100 110 107 ...  64  71  59]
# ./ATnT/s9/2.pgm
# Best match ./ATnT/s9/3.pgm with Euclidean distance 1644.310583
# [63 60 63 ... 63 69 58]
# ./ATnT/s16/8.pgm
# Best match ./ATnT/s16/9.pgm with Euclidean distance 2805.587680
# [45 49 47 ... 40 30 44]
# ./ATnT/s11/6.pgm
# Best match ./ATnT/s11/1.pgm with Euclidean distance 2160.860223
# [124 124 123 ...  99 102  95]
# ./ATnT/s25/4.pgm
# Best match ./ATnT/s25/5.pgm with Euclidean distance 1962.776181
# [51 41 56 ... 43 49 36]
# ./ATnT/s19/2.pgm
# Best match ./ATnT/s19/1.pgm with Euclidean distance 1075.758842
# [52 47 51 ... 30 34 42]
# ./ATnT/s37/2.pgm
# Best match ./ATnT/s37/6.pgm with Euclidean distance 1339.945712
# [63 67 65 ... 54 61 69]
# ./ATnT/s36/1.pgm
# Best match ./ATnT/s36/5.pgm with Euclidean distance 2127.129722
# [116 116 117 ...  19  24  16]
# ./ATnT/s20/4.pgm
# Best match ./ATnT/s20/6.pgm with Euclidean distance 900.310932
# [118 123 120 ...  79  81  84]
# ./ATnT/s18/6.pgm
# Best match ./ATnT/s18/8.pgm with Euclidean distance 1549.012891
# [105 110 106 ...  18  27  22]
# ./ATnT/s13/10.pgm
# Best match ./ATnT/s13/5.pgm with Euclidean distance 898.728556
# [155 154 153 ... 113 110 111]
# ./ATnT/s6/8.pgm
# Best match ./ATnT/s6/6.pgm with Euclidean distance 1426.272220
# [126 130 131 ...  43  51  48]
# ./ATnT/s8/1.pgm
# Best match ./ATnT/s8/2.pgm with Euclidean distance 1244.033297
# [39 43 39 ... 24 24 23]
# ./ATnT/s27/8.pgm
# Best match ./ATnT/s27/9.pgm with Euclidean distance 1193.438030
# [104 106 105 ... 148 155 168]
# ./ATnT/s21/7.pgm
# Best match ./ATnT/s21/10.pgm with Euclidean distance 1814.124882
# [ 96  94  98 ... 131 136 152]
# ./ATnT/s31/8.pgm
# Best match ./ATnT/s31/1.pgm with Euclidean distance 1280.931901
# [116 119 117 ...  60  54  64]
# ./ATnT/s23/5.pgm
# Best match ./ATnT/s23/3.pgm with Euclidean distance 1168.541637
# [101 106 102 ...  46  50  45]
# ./ATnT/s3/3.pgm
# Best match ./ATnT/s3/2.pgm with Euclidean distance 1449.566521
# [109 105 112 ...  55  50  51]
# ./ATnT/s26/1.pgm
# Best match ./ATnT/s26/6.pgm with Euclidean distance 1874.583099
# [108 112 109 ...  73  64  69]
# ./ATnT/s38/9.pgm
# Best match ./ATnT/s38/1.pgm with Euclidean distance 1942.941574
# [48 48 55 ... 88 93 99]
# ./ATnT/s28/5.pgm
# Best match ./ATnT/s28/2.pgm with Euclidean distance 1533.372058
# [135 133 136 ...  18  21  24]
# ./ATnT/s10/8.pgm
# Best match ./ATnT/s10/2.pgm with Euclidean distance 1737.304933
# [ 97  94  92 ... 144 143 129]
# ./ATnT/s39/6.pgm
# Best match ./ATnT/s39/10.pgm with Euclidean distance 1858.037452
# [38 33 43 ... 26 28 23]
# ./ATnT/s32/3.pgm
# Best match ./ATnT/s32/2.pgm with Euclidean distance 1628.890966

# %%
# for keys in components_res_dict:
#   print(keys, components_res_dict[keys])

# %%
# plot the eigen faces
# %matplotlib inline
# Generate random images for demonstration
num_images = len(y_test)

# Create a figure and subplots
fig, axes = plt.subplots(1, num_images, figsize=(25, 1))

# Plot first row of images
# count = 0
for i in range(num_images):
    col = i % 40
    face = att_faces_dict[y_test[i]].reshape((112, 92))
    axes[col].imshow(face, cmap='gray')
    axes[col].axis('off')

# for i in range(num_images):
#     col = i % 40
#     face = att_faces_dict[y_test[i]].reshape((112, 92))
#     axes[1, col].imshow(face, cmap='gray')
#     axes[1, col].axis('off')

plt.show()
print()
print()

# Create a figure and subplots
for keys in components_res_dict:
    fig, axes = plt.subplots(1, num_images, figsize=(25, 1))
    for i in range(num_images):
        col = i % 40
        face = reconstructed_faces_res_dict[keys][i].reshape((112, 92))
        axes[col].imshow(face, cmap='gray')
        axes[col].axis('off')
    plt.show()
    fig, axes = plt.subplots(1, num_images, figsize=(25, 1))
    for i in range(num_images):
        col = i % 40
        # print(components_res_dict[keys])
        face = att_faces_dict[components_res_dict[keys][i][1]].reshape((112, 92))
        axes[col].imshow(face, cmap='gray')
        axes[col].axis('off')
    plt.show()
    print()
    print()

# %%
# your code here
accuracy_list_2 = []

for keys in components_res_dict:
    components_res_dict_list = components_res_dict[keys]
    total_instances = len(components_res_dict_list)
    cnt = 0
    for i in range(len(components_res_dict_list)):
        if(components_res_dict_list[i][2] == True):
            cnt += 1
    accuracy_list_2.append(cnt/total_instances)

print(components_list)
print(accuracy_list_2)

import matplotlib.pyplot as plt

plt.plot(components_list, accuracy_list_2, 'bx-')
plt.xlabel('No of components')
plt.ylabel('Accuracy')
plt.title('Accuracy of Image Compression using PCA')
plt.show()
# Out:
# [3, 5, 10, 20, 30, 40, 50, 100]
# [0.8, 0.9, 0.975, 0.975, 0.975, 0.975, 0.975, 0.975]

# %% [markdown]
# #MSEs

# %%
# your code here
MSE_list_2 = []
log_MSE_list_2 = []

for keys in components_res_dict:
    MSE_list_2.append(components_res_dict[keys][1][3])
    log_MSE_list_2.append(components_res_dict[keys][1][4])

print(components_list)
print(MSE_list_2)
print(log_MSE_list_2)
# Out:
# [3, 5, 10, 20, 30, 40, 50, 100]
# [395.4254802166236, 507.03504014731465, 606.7105708963286, 731.3654723883243, 861.9599096591784, 937.4709487413842, 1001.8020324720144, 1225.6790739703408]
# [5.979962350280435, 6.228580113919606, 6.40805185839351, 6.594913297037835, 6.7592087610661045, 6.843185769355237, 6.909555689741596, 7.1112503154840265]

# %% [markdown]
# Plot Number of eigenvectors vs Mean Square Error

# %%
plt.plot(components_list, MSE_list_2, 'bx-')
plt.xlabel('No of components')
plt.ylabel('Mean Square Error')
plt.title('Mean Square Error of Image Compression using PCA for single test image')
plt.show()

# %% [markdown]
# Plot Number of eigenvectors vs Logarithmic Mean Square Error

# %%
plt.plot(components_list, log_MSE_list_2, 'bx-')
plt.xlabel('No of components')
plt.ylabel('Log of Mean Square Error')
plt.title('Log of Mean Square Error of Image Compression using PCA for single test image')
plt.show()
